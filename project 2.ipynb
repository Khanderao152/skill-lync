# %%
import pandas as pd

# %%
df1 =pd.read_csv('customer_details.csv')

# %%
df2 =pd.read_csv('customer_policy_details.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       380723 non-null  float64
#  1   1       380741 non-null  object
#  2   2       380741 non-null  float64
#  3   3       380716 non-null  float64
#  4   4       380717 non-null  float64
#  5   5       380728 non-null  float64
#  6   6       380728 non-null  object
#  7   7       380702 non-null  object
# dtypes: float64(5), object(3)
# memory usage: 23.3+ MB

# %%
df2.info
# Out:
# <bound method DataFrame.info of                0        1      2      3    4
# 0            1.0  40454.0   26.0  217.0  1.0
# 1            2.0  33536.0   26.0  183.0  0.0
# 2            3.0  38294.0   26.0   27.0  1.0
# 3            4.0  28619.0  152.0  203.0  0.0
# 4            5.0  27496.0  152.0   39.0  0.0
# ...          ...      ...    ...    ...  ...
# 381104  381105.0  30170.0   26.0   88.0  0.0
# 381105  381106.0  40016.0  152.0  131.0  0.0
# 381106  381107.0  35118.0  160.0  161.0  0.0
# 381107  381108.0  44617.0  124.0   74.0  0.0
# 381108  381109.0  41777.0   26.0  237.0  0.0
#
# [381109 rows x 5 columns]>

# %%
df1.columns =['customer_id','gender','age','draving_l','region_code','previously_insured','vehicle_age','vehicle_damage']

# %%
df1
# Out:
#         customer_id  gender   age  draving_l  region_code  previously_insured  \
# 0               1.0    Male  44.0        1.0         28.0                 0.0
# 1               2.0    Male  76.0        1.0          3.0                 0.0
# 2               3.0    Male  47.0        1.0         28.0                 0.0
# 3               4.0    Male  21.0        1.0         11.0                 1.0
# 4               5.0  Female  29.0        1.0         41.0                 1.0
# ...             ...     ...   ...        ...          ...                 ...
# 381104     381105.0    Male  74.0        1.0         26.0                 1.0
# 381105     381106.0    Male  30.0        1.0         37.0                 1.0
# 381106     381107.0    Male  21.0        1.0         30.0                 1.0
# 381107     381108.0  Female  68.0        1.0         14.0                 0.0
# 381108     381109.0    Male  46.0        1.0         29.0                 0.0
#
# ...

# %%
df2.columns =['customer_id','annual premium','sales channel code','vintage','response']

# %%
df2
# Out:
#         customer_id  annual premium  sales channel code  vintage  response
# 0               1.0         40454.0                26.0    217.0       1.0
# 1               2.0         33536.0                26.0    183.0       0.0
# 2               3.0         38294.0                26.0     27.0       1.0
# 3               4.0         28619.0               152.0    203.0       0.0
# 4               5.0         27496.0               152.0     39.0       0.0
# ...             ...             ...                 ...      ...       ...
# 381104     381105.0         30170.0                26.0     88.0       0.0
# 381105     381106.0         40016.0               152.0    131.0       0.0
# 381106     381107.0         35118.0               160.0    161.0       0.0
# 381107     381108.0         44617.0               124.0     74.0       0.0
# 381108     381109.0         41777.0                26.0    237.0       0.0
#
# [381109 rows x 5 columns]

# %%
df2.isnull().sum()
# Out:
# customer_id           387
# annual premium        346
# sales channel code    400
# vintage               388
# response              361
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# customer_id           386
# gender                368
# age                   368
# draving_l             393
# region_code           392
# previously_insured    381
# vehicle_age           381
# vehicle_damage        407
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   customer_id         380723 non-null  float64
#  1   gender              380741 non-null  object
#  2   age                 380741 non-null  float64
#  3   draving_l           380716 non-null  float64
#  4   region_code         380717 non-null  float64
#  5   previously_insured  380728 non-null  float64
#  6   vehicle_age         380728 non-null  object
#  7   vehicle_damage      380702 non-null  object
# dtypes: float64(5), object(3)
# memory usage: 23.3+ MB

# %%
df1.fillna(df1.mean)
# Out:
#        customer_id  gender   age draving_l region_code previously_insured  \
# 0              1.0    Male  44.0       1.0        28.0                0.0
# 1              2.0    Male  76.0       1.0         3.0                0.0
# 2              3.0    Male  47.0       1.0        28.0                0.0
# 3              4.0    Male  21.0       1.0        11.0                1.0
# 4              5.0  Female  29.0       1.0        41.0                1.0
# ...            ...     ...   ...       ...         ...                ...
# 381104    381105.0    Male  74.0       1.0        26.0                1.0
# 381105    381106.0    Male  30.0       1.0        37.0                1.0
# 381106    381107.0    Male  21.0       1.0        30.0                1.0
# 381107    381108.0  Female  68.0       1.0        14.0                0.0
# 381108    381109.0    Male  46.0       1.0        29.0                0.0
#
#        vehicle_age vehicle_damage
# 0        > 2 Years            Yes
# ...

# %%
df2.fillna(df2.mean)
# Out:
#        customer_id annual premium sales channel code vintage response
# 0              1.0        40454.0               26.0   217.0      1.0
# 1              2.0        33536.0               26.0   183.0      0.0
# 2              3.0        38294.0               26.0    27.0      1.0
# 3              4.0        28619.0              152.0   203.0      0.0
# 4              5.0        27496.0              152.0    39.0      0.0
# ...            ...            ...                ...     ...      ...
# 381104    381105.0        30170.0               26.0    88.0      0.0
# 381105    381106.0        40016.0              152.0   131.0      0.0
# 381106    381107.0        35118.0              160.0   161.0      0.0
# 381107    381108.0        44617.0              124.0    74.0      0.0
# 381108    381109.0        41777.0               26.0   237.0      0.0
#
# [381109 rows x 5 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   customer_id         380722 non-null  float64
#  1   annual premium      380763 non-null  float64
#  2   sales channel code  380709 non-null  float64
#  3   vintage             380721 non-null  float64
#  4   response            380748 non-null  float64
# dtypes: float64(5)
# memory usage: 14.5 MB

# %%
pd.get_dummies(df1['gender'])
# Out:
#         Female  Male
# 0            0     1
# 1            0     1
# 2            0     1
# 3            0     1
# 4            1     0
# ...        ...   ...
# 381104       0     1
# 381105       0     1
# 381106       0     1
# 381107       1     0
# 381108       0     1
#
# [381109 rows x 2 columns]

# %%
pd.get_dummies(df1['gender'],drop_first=True)
# Out:
#         Male
# 0          1
# 1          1
# 2          1
# 3          1
# 4          0
# ...      ...
# 381104     1
# 381105     1
# 381106     1
# 381107     0
# 381108     1
#
# [381109 rows x 1 columns]

# %%
G_dummy = pd.get_dummies(df1['gender'],drop_first=True)

# %%
G_dummy.head()
# Out:
#    Male
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0

# %%
pd.get_dummies(df1['vehicle_age'])
# Out:
#         1-2 Year  < 1 Year  > 2 Years
# 0              0         0          1
# 1              1         0          0
# 2              0         0          1
# 3              0         1          0
# 4              0         1          0
# ...          ...       ...        ...
# 381104         1         0          0
# 381105         0         1          0
# 381106         0         1          0
# 381107         0         0          1
# 381108         1         0          0
#
# [381109 rows x 3 columns]

# %%
pd.get_dummies(df1['vehicle_age'],drop_first=True)
# Out:
#         < 1 Year  > 2 Years
# 0              0          1
# 1              0          0
# 2              0          1
# 3              1          0
# 4              1          0
# ...          ...        ...
# 381104         0          0
# 381105         1          0
# 381106         1          0
# 381107         0          1
# 381108         0          0
#
# [381109 rows x 2 columns]

# %%
V_age=pd.get_dummies(df1['vehicle_age'],drop_first=True)

# %%
pd.get_dummies(df1['vehicle_damage'])
# Out:
#         No  Yes
# 0        0    1
# 1        1    0
# 2        0    1
# 3        1    0
# 4        1    0
# ...     ..  ...
# 381104   1    0
# 381105   1    0
# 381106   1    0
# 381107   0    1
# 381108   1    0
#
# [381109 rows x 2 columns]

# %%
pd.get_dummies(df1['vehicle_damage'],drop_first=True)
# Out:
#         Yes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
# ...     ...
# 381104    0
# 381105    0
# 381106    0
# 381107    1
# 381108    0
#
# [381109 rows x 1 columns]

# %%
V_damage=pd.get_dummies(df1['vehicle_damage'],drop_first=True)

# %%
df1=pd.concat([df1,V_damage,V_age],axis=1)

# %%
df1.head()
# Out:
#    customer_id  gender   age  draving_l  region_code  previously_insured  \
# 0          1.0    Male  44.0        1.0         28.0                 0.0
# 1          2.0    Male  76.0        1.0          3.0                 0.0
# 2          3.0    Male  47.0        1.0         28.0                 0.0
# 3          4.0    Male  21.0        1.0         11.0                 1.0
# 4          5.0  Female  29.0        1.0         41.0                 1.0
#
#   vehicle_age vehicle_damage  Yes  < 1 Year  > 2 Years
# 0   > 2 Years            Yes    1         0          1
# 1    1-2 Year             No    0         0          0
# 2   > 2 Years            Yes    1         0          1
# 3    < 1 Year             No    0         1          0
# 4    < 1 Year             No    0         1          0

# %%
df1.drop(['vehicle_age','gender','vehicle_damage'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    customer_id   age  draving_l  region_code  previously_insured  Yes  \
# 0          1.0  44.0        1.0         28.0                 0.0    1
# 1          2.0  76.0        1.0          3.0                 0.0    0
# 2          3.0  47.0        1.0         28.0                 0.0    1
# 3          4.0  21.0        1.0         11.0                 1.0    0
# 4          5.0  29.0        1.0         41.0                 1.0    0
#
#    < 1 Year  > 2 Years
# 0         0          1
# 1         0          0
# 2         0          1
# 3         1          0
# 4         1          0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   customer_id         380723 non-null  float64
#  1   age                 380741 non-null  float64
#  2   draving_l           380716 non-null  float64
#  3   region_code         380717 non-null  float64
#  4   previously_insured  380728 non-null  float64
#  5   Yes                 381109 non-null  uint8
#  6   < 1 Year            381109 non-null  uint8
#  7   > 2 Years           381109 non-null  uint8
# dtypes: float64(5), uint8(3)
# memory usage: 15.6 MB

# %%
df3=pd.merge(df1,df2,on='customer_id')

# %%
df3.head()
# Out:
#    customer_id   age  draving_l  region_code  previously_insured  Yes  \
# 0          1.0  44.0        1.0         28.0                 0.0    1
# 1          2.0  76.0        1.0          3.0                 0.0    0
# 2          3.0  47.0        1.0         28.0                 0.0    1
# 3          4.0  21.0        1.0         11.0                 1.0    0
# 4          5.0  29.0        1.0         41.0                 1.0    0
#
#    < 1 Year  > 2 Years  annual premium  sales channel code  vintage  response
# 0         0          1         40454.0                26.0    217.0       1.0
# 1         0          0         33536.0                26.0    183.0       0.0
# 2         0          1         38294.0                26.0     27.0       1.0
# 3         1          0         28619.0               152.0    203.0       0.0
# 4         1          0         27496.0               152.0     39.0       0.0

# %%
result=df3.groupby('G_dummy')['annual premium']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 result=df3.groupby('G_dummy')['annual premium']
#
# NameError: name 'df3' is not defined

# %%
result1=df3.groupby('age')['annual premium'].mean()

# %%
import matplotlib.pyplot as pyplot

# %%
result1.plot()
# Out:
# <AxesSubplot:xlabel='age'>

# %%
pyplot.show()

# %%
print(f"male to female ration is {round(df3['G_dummy'].value_counts()[0]/df3['G_dummy'].value_counts()[1],2)}")
print(f"generally, the standard is: \n balanced data ratio: {50/50}\n slightly balanced data ratio: {round(55/45,2)}-{60/40} \n imbalanced data ratio: {80/20}-{90/10}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'G_dummy'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
result4_4 = df3.groupby('V_age')['annual premium'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 result4_4 = df3.groupby('V_age')['annual premium'].mean()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
n = df3['age'].corr(df3['annual premium'])
if n<-0.5:
    print("Strong negative relationship")
if n>0.5:
    print("Strong positive relationship")
if n>-0.5 and n<0.5:
    print("There is no relationship!")
# Out:
# There is no relationship!
